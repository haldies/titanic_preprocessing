# %% [markdown]
# # 1. Perkenalan Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 3. Memuat Dataset

# %%
df_train = pd.read_csv('../titanic_raw/train.csv')
df_test = pd.read_csv('../titanic_raw/test.csv')

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # 4. Exploratory Data Analysis (EDA)

# %%
print(df_test.describe())
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
print(df_train.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.set(style="whitegrid")

# 1. Distribusi target variable 'Survived'
plt.figure(figsize=(6,4))
sns.countplot(x='Survived', data=df_train)
plt.title('Distribusi Survived')
plt.show()

# 2. Distribusi kategori 'Pclass'
plt.figure(figsize=(6,4))
sns.countplot(x='Pclass', data=df_train)
plt.title('Distribusi Pclass')
plt.show()

# 3. Distribusi kategori 'Sex'
plt.figure(figsize=(6,4))
sns.countplot(x='Sex', data=df_train)
plt.title('Distribusi Sex')
plt.show()

# 4. Distribusi continuous 'Age' (histogram)
plt.figure(figsize=(8,4))
sns.histplot(df_train['Age'].dropna(), bins=30, kde=True)
plt.title('Distribusi Age')
plt.show()

# 5. Distribusi 'SibSp' (jumlah saudara/istri)
plt.figure(figsize=(6,4))
sns.countplot(x='SibSp', data=df_train)
plt.title('Distribusi SibSp')
plt.show()

# 6. Distribusi 'Parch' (jumlah orang tua/anak)
plt.figure(figsize=(6,4))
sns.countplot(x='Parch', data=df_train)
plt.title('Distribusi Parch')
plt.show()

# 7. Distribusi 'Fare' (continuous, bisa pakai boxplot atau hist)
plt.figure(figsize=(8,4))
sns.histplot(df_train['Fare'], bins=30, kde=True)
plt.title('Distribusi Fare')
plt.show()

# 8. Distribusi 'Embarked' (kategori pelabuhan naik)
plt.figure(figsize=(6,4))
sns.countplot(x='Embarked', data=df_train)
plt.title('Distribusi Embarked')
plt.show()

# %% [markdown]
# ### 1. **Survived (Target)**
#
# * Jumlah yang tidak selamat (0) jauh lebih banyak, 549 vs 342 yang selamat.
# * Imbalance kelas cukup signifikan, tapi tidak ekstrim. Model bisa belajar dari ini, tapi perlu waspada supaya tidak bias ke kelas mayoritas.
#
# ### 2. **Pclass (Tingkat kelas tiket)**
#
# * Mayoritas penumpang ada di kelas 3 (491), lalu kelas 1 (216), dan kelas 2 (184).
# * Ini biasanya berpengaruh besar ke tingkat kelangsungan hidup, karena kelas 1 dan 2 punya akses lebih cepat ke penyelamatan.
#
# ### 3. **Sex**
#
# * Jumlah laki-laki (577) lebih banyak dibanding perempuan (314).
# * Berdasarkan sejarah Titanic, perempuan punya kemungkinan bertahan hidup lebih besar, ini penting untuk analisis lanjutan.
#
# ### 4. **Age**
#
# * Usia rata-rata sekitar 29 tahun dengan rentang cukup luas (0.42 - 80 tahun).
# * Distribusi usia kemungkinan cenderung normal atau sedikit miring, ada banyak penumpang muda dan dewasa.
# * Ada kemungkinan missing value di usia, perlu dicek.
#
# ### 5. **SibSp (Jumlah saudara/istri)**
#
# * Kebanyakan penumpang tidak membawa saudara atau pasangan (608).
# * Ada beberapa dengan jumlah keluarga cukup besar (hingga 8).
# * Bisa jadi yang traveling sendiri punya peluang bertahan yang berbeda dibanding yang bersama keluarga.
#
# ### 6. **Parch (Jumlah orang tua/anak)**
#
# * Mayoritas juga tidak membawa orang tua/anak (678).
# * Mirip dengan SibSp, jumlah keluarga bisa pengaruh ke tingkat kelangsungan hidup.
#
# ### 7. **Fare (Harga tiket)**
#
# * Harga tiket sangat bervariasi, dari 0 sampai lebih dari 500.
# * Median di sekitar 14.45, tapi ada outlier harga sangat tinggi.
# * Harga tiket biasanya berkorelasi dengan kelas dan akses penyelamatan.
#
# ### 8. **Embarked (Pelabuhan naik)**
#
# * Mayoritas naik dari pelabuhan 'S' (Southampton) sebanyak 646, kemudian 'C' (Cherbourg) dan 'Q' (Queenstown).
# * Ini juga bisa berpengaruh ke survival karena lokasi dan profil penumpang berbeda.

# %% [markdown]
# # 5. Data Preprocessing

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df_test.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_train.drop(columns=["Name", "Cabin", "PassengerId", ], inplace=True)
df_test.drop(columns=["Name", "Cabin", "PassengerId", ], inplace=True)

# %%
df_train['Age'] = df_train['Age'].fillna(df_train['Age'].median())
print(df_train.isnull().sum())
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df_test['Age'] = df_test['Age'].fillna(df_test['Age'].median())
print(df_test.isnull().sum())
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        1
# Embarked    0
# dtype: int64

# %%
median_fare = df_test['Fare'].median()
df_test['Fare'] = df_test['Fare'].fillna(median_fare)
print(df_test.isnull().sum())
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
mode_embarked = df_train['Embarked'].mode()[0]
df_train['Embarked'] = df_train['Embarked'].fillna(mode_embarked)
print(df_train.isnull().sum())
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
def preprocess(df):
    df = df.copy()
    
    def ticket_number(x):
        return x.split(" ")[-1]
        
    def ticket_item(x):
        items = x.split(" ")
        if len(items) == 1:
            return "NONE"
        return "_".join(items[0:-1])
    df["Ticket_number"] = df["Ticket"].apply(ticket_number)
    df["Ticket_item"] = df["Ticket"].apply(ticket_item)                     
    return df
    
preprocessed_train_df = preprocess(df_train)
preprocessed_serving_df = preprocess(df_test)


preprocessed_train_df.to_csv('../preprocessing/titanic_preprocessing/titanic_preprocessed_train.csv', index=False)
preprocessed_serving_df.to_csv('../preprocessing/titanic_preprocessing/titanic_preprocessed_test.csv', index=False)

preprocessed_train_df.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked Ticket_number Ticket_item
# 0        S         21171         A/5
# 1        C         17599          PC
# 2        S       3101282    STON/O2.
# 3        S        113803        NONE
# 4        S        373450        NONE
